# %% [raw]
# ---
# skip_exec: true
# ---

# %% [markdown]
# # Some simple functions
#
# > Here are some simple functions we'll need

# %%
#| This module adds the following functions: add, multiply. It also uses them

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
def add(x,y):
    "Multiply two numbers"
    return x+y

def multiply(x,y):
    return x*y

# %%
x = 5
y = 10
multiply(x,y)
# Out:
# 50

# %%
x = 10
y = 5
add(x,y)
# Out:
# 15

# %%
#| hide
import nbdev; nbdev.nbdev_export()
